# %%
import numpy as np
x = np.linspace(0, 10, 100)  # Generate 100 evenly spaced values from 0 to 10
y = np.sin(x)  # Calculate sine values for x

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')
